# %%
# !pip uninstall ultralytics
# Out:
# WARNING: Skipping ultralytics as it is not installed.

# %%
# !pip install gitpython
# Out:
# ERROR: Could not find a version that satisfies the requirement requirements.txt (from versions: none)
# HINT: You are attempting to install a package literally named "requirements.txt" (which cannot exist). Consider using the '-r' flag to install the packages listed in requirements.txt
# ERROR: No matching distribution found for requirements.txt

# %%
# !pip install PyYAML psutil requests
# Out:
# Collecting PyYAML
#   Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: psutil in ./YoloVenv/lib/python3.12/site-packages (7.0.0)
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 6.3 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (145 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Installing collected packages: urllib3, PyYAML, idna, charset-normalizer, certifi, requests
# Successfully installed PyYAML-6.0.2 certifi-2025.1.31 charset-normalizer-3.4.1 idna-3.10 requests-2.32.3 urllib3-2.4.0

# %%
# %pip install roboflow
# Out:
# Requirement already satisfied: roboflow in ./YoloVenv/lib/python3.12/site-packages (1.1.61)
# Requirement already satisfied: certifi in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (2025.1.31)
# Requirement already satisfied: idna==3.7 in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (3.10.1)
# Requirement already satisfied: numpy>=1.18.5 in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (2.1.1)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (11.2.1)
# Requirement already satisfied: pillow-heif>=0.18.0 in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (0.22.0)
# Requirement already satisfied: python-dateutil in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (1.1.0)
# Collecting requests (from roboflow)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (4.67.1)
# Collecting PyYAML>=5.3.1 (from roboflow)
#   Using cached PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: requests-toolbelt in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in ./YoloVenv/lib/python3.12/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./YoloVenv/lib/python3.12/site-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./YoloVenv/lib/python3.12/site-packages (from matplotlib->roboflow) (4.57.0)
# Requirement already satisfied: packaging>=20.0 in ./YoloVenv/lib/python3.12/site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in ./YoloVenv/lib/python3.12/site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./YoloVenv/lib/python3.12/site-packages (from requests->roboflow) (3.4.1)
# Using cached PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Installing collected packages: requests, PyYAML
# Successfully installed PyYAML-6.0.2 requests-2.32.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in ./YoloVenv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./YoloVenv/lib/python3.12/site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: pandas>=1.2 in ./YoloVenv/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./YoloVenv/lib/python3.12/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./YoloVenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./YoloVenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./YoloVenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./YoloVenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./YoloVenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in ./YoloVenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./YoloVenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./YoloVenv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./YoloVenv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./YoloVenv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in ./YoloVenv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
# !train.py  --data data/coco.yaml --img 640 --batch 32 --conf 0.001 --iou 0.65 --device cpu --weights yolov7.pt --name yolov7_640_val
# Out:
# usage: train.py [-h] [--weights WEIGHTS] [--cfg CFG] [--data DATA] [--hyp HYP]
#                 [--epochs EPOCHS] [--batch-size BATCH_SIZE]
#                 [--img-size IMG_SIZE [IMG_SIZE ...]] [--rect]
#                 [--resume [RESUME]] [--nosave] [--notest] [--noautoanchor]
#                 [--evolve] [--bucket BUCKET] [--cache-images]
#                 [--image-weights] [--device DEVICE] [--multi-scale]
#                 [--single-cls] [--adam] [--sync-bn] [--local_rank LOCAL_RANK]
#                 [--workers WORKERS] [--project PROJECT] [--entity ENTITY]
#                 [--name NAME] [--exist-ok] [--quad] [--linear-lr]
#                 [--label-smoothing LABEL_SMOOTHING] [--upload_dataset]
#                 [--bbox_interval BBOX_INTERVAL] [--save_period SAVE_PERIOD]
#                 [--artifact_alias ARTIFACT_ALIAS]
#                 [--freeze FREEZE [FREEZE ...]] [--v5-metric]
# train.py: error: unrecognized arguments: --conf 0.001 --iou 0.65

# %%
import ultralytics
from ultralytics import YOLO
import cv2

model = YOLO("yolov8n.pt")

results = model.predict(source="0", show=True)

print(results)
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/n0blespeasant/Desktop/Yolov5Traffic/YoloVenv/lib/python3.12/site-packages/cv2/qt/plugins"
# 1/1: 0... Success ✅ (inf frames of shape 640x480 at 30.00 FPS)
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 (no detections), 303.7ms
# 0: 480x640 (no detections), 258.0ms
# 0: 480x640 (no detections), 234.4ms
# 0: 480x640 (no detections), 191.5ms
# 0: 480x640 (no detections), 184.8ms
# 0: 480x640 (no detections), 188.3ms
# 0: 480x640 (no detections), 183.6ms
# 0: 480x640 (no detections), 185.0ms
# 0: 480x640 (no detections), 184.1ms
# 0: 480x640 (no detections), 174.2ms
# 0: 480x640 (no detections), 172.9ms
# 0: 480x640 (no detections), 179.7ms
# 0: 480x640 (no detections), 210.2ms
# 0: 480x640 (no detections), 194.1ms
# 0: 480x640 (no detections), 166.4ms
# 0: 480x640 (no detections), 165.9ms
# 0: 480x640 (no detections), 189.3ms
# 0: 480x640 (no detections), 173.0ms
# 0: 480x640 (no detections), 163.9ms
# 0: 480x640 (no detections), 175.4ms
# 0: 480x640 (no detections), 165.3ms
# 0: 480x640 (no detections), 175.1ms
# 0: 480x640 (no detections), 182.8ms
# 0: 480x640 (no detections), 183.8ms
# 0: 480x640 (no detections), 162.1ms
# 0: 480x640 (no detections), 159.5ms
# 0: 480x640 (no detections), 154.2ms
# 0: 480x640 (no detections), 147.6ms
# 0: 480x640 (no detections), 159.9ms
# 0: 480x640 (no detections), 150.3ms
# 0: 480x640 (no detections), 163.9ms
# 0: 480x640 (no detections), 184.7ms
# 0: 480x640 (no detections), 199.2ms
# 0: 480x640 (no detections), 174.9ms
# 0: 480x640 (no detections), 194.9ms
# 0: 480x640 (no detections), 162.2ms
# 0: 480x640 (no detections), 165.7ms
# 0: 480x640 (no detections), 180.5ms
# 0: 480x640 (no detections), 164.8ms
# 0: 480x640 (no detections), 166.2ms
# 0: 480x640 (no detections), 174.5ms
# 0: 480x640 (no detections), 173.0ms
# 0: 480x640 (no detections), 258.0ms
# 0: 480x640 (no detections), 185.0ms
# 0: 480x640 (no detections), 195.4ms
# 0: 480x640 (no detections), 217.6ms
# 0: 480x640 (no detections), 173.7ms
# 0: 480x640 (no detections), 188.1ms
# 0: 480x640 (no detections), 186.1ms
# 0: 480x640 (no detections), 247.4ms
# 0: 480x640 (no detections), 253.9ms
# 0: 480x640 (no detections), 207.5ms
# 0: 480x640 (no detections), 157.8ms
# 0: 480x640 (no detections), 189.2ms
# 0: 480x640 (no detections), 195.1ms
# 0: 480x640 (no detections), 183.3ms
# 0: 480x640 (no detections), 173.3ms
# 0: 480x640 (no detections), 168.0ms
# 0: 480x640 (no detections), 191.7ms
# 0: 480x640 (no detections), 192.4ms
# 0: 480x640 (no detections), 180.5ms
# 0: 480x640 (no detections), 158.3ms
# 0: 480x640 (no detections), 232.9ms
# 0: 480x640 (no detections), 168.2ms
# 0: 480x640 (no detections), 211.9ms
# 0: 480x640 (no detections), 174.1ms
# 0: 480x640 (no detections), 158.9ms
# 0: 480x640 (no detections), 261.5ms
# 0: 480x640 (no detections), 211.6ms
# 0: 480x640 (no detections), 236.5ms
# 0: 480x640 (no detections), 211.3ms
# 0: 480x640 (no detections), 223.9ms
# 0: 480x640 (no detections), 203.8ms
# 0: 480x640 (no detections), 186.5ms
# 0: 480x640 (no detections), 191.0ms
# 0: 480x640 (no detections), 213.9ms
# 0: 480x640 (no detections), 214.6ms
# 0: 480x640 (no detections), 191.8ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       3 import cv2
#       5 model = YOLO("yolov8n.pt")
# ----> 7 results = model.predict(source="0", show=True)
#       9 print(results)
#
# File ~/Desktop/Yolov5Traffic/YoloVenv/lib/python3.12/site-packages/ultralytics/engine/model.py:549, in Model.predict(self, source, stream, predictor, **kwargs)
#     547 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     548     self.predictor.set_prompts(prompts)
# --> 549 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Desktop/Yolov5Traffic/YoloVenv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:216, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     214     return self.stream_inference(source, model, *args, **kwargs)
#     215 else:
# --> 216     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/Desktop/Yolov5Traffic/YoloVenv/lib/python3.12/site-packages/torch/utils/_contextlib.py:57, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      54         else:
#      55             # Pass the last request to the generator and get its response
#      56             with ctx_factory():
# ---> 57                 response = gen.send(request)
#      59 # We let the exceptions raised above by the generator's `.throw` or
#      60 # `.send` methods bubble up to our caller, except for StopIteration
#      61 except StopIteration as e:
#      62     # The generator informed us that it is done: take whatever its
#      63     # returned value (if any) was and indicate that we're done too
#      64     # by returning it (see docs for python's return-statement).
#
# File ~/Desktop/Yolov5Traffic/YoloVenv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:347, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     341     self.results[i].speed = {
#     342         "preprocess": profilers[0].dt * 1e3 / n,
#     343         "inference": profilers[1].dt * 1e3 / n,
#     344         "postprocess": profilers[2].dt * 1e3 / n,
#     345     }
#     346     if self.args.verbose or self.args.save or self.args.save_txt or self.args.show:
# --> 347         s[i] += self.write_results(i, Path(paths[i]), im, s)
#     349 # Print batch results
#     350 if self.args.verbose:
#
# File ~/Desktop/Yolov5Traffic/YoloVenv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:442, in BasePredictor.write_results(self, i, p, im, s)
#     440     result.save_crop(save_dir=self.save_dir / "crops", file_name=self.txt_path.stem)
#     441 if self.args.show:
# --> 442     self.show(str(p))
#     443 if self.args.save:
#     444     self.save_predicted_images(str(self.save_dir / p.name), frame)
#
# File ~/Desktop/Yolov5Traffic/YoloVenv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:490, in BasePredictor.show(self, p)
#     488     cv2.resizeWindow(p, im.shape[1], im.shape[0])  # (width, height)
#     489 cv2.imshow(p, im)
# --> 490 cv2.waitKey(300 if self.dataset.mode == "image" else 1)
#
# KeyboardInterrupt:

# %%
from ultralytics import YOLO
import cv2

model = YOLO('yolov8n.pt')

cap = cv2.VideoCapture(1)

if not cap.isOpened():
    print("failed to open webcam")
    exit()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ultralytics import YOLO
#       2 import cv2
#       4 model = YOLO('yolov8n.pt')
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
model = YOLO("yolov8n.yaml")

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolov8n.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="coco8.yaml", epochs=3)
s
# Evaluate the model's performance on the validation set
results = model.val()

# Perform object detection on an image using the model
results = model("https://ultralytics.com/images/bus.jpg")

# Export the model to ONNX format
success = model.export(format="onnx")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 9.42MB/s]
# New https://pypi.org/project/ultralytics/8.3.112 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.109 🚀 Python-3.12.9 torch-2.6.0+cu124 CPU (12th Gen Intel Core(TM) i5-1245U)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=coco8.yaml, epochs=3, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
#
# Dataset 'coco8.yaml' images not found ⚠️, missing path '/home/n0blespeasant/Desktop/Yolov5Traffic/datasets/coco8/images/val'
# Downloading https://ultralytics.com/assets/coco8.zip to '/home/n0blespeasant/Desktop/Yolov5Traffic/datasets/coco8.zip'...
# 100%|██████████| 433k/433k [00:00<00:00, 4.91MB/s]
# Unzipping /home/n0blespeasant/Desktop/Yolov5Traffic/datasets/coco8.zip to /home/n0blespeasant/Desktop/Yolov5Traffic/datasets/coco8...: 100%|██████████| 25/25 [00:00<00:00, 2223.11file/s]
# Dataset download success ✅ (0.6s), saved to /home/n0blespeasant/Desktop/Yolov5Traffic/datasets
# Downloading https://ultralytics.com/assets/Arial.ttf to '/home/n0blespeasant/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 5.49MB/s]
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    897664  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# Model summary: 129 layers, 3,157,200 parameters, 3,157,184 gradients, 8.9 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /home/n0blespeasant/Desktop/Yolov5Traffic/datasets/coco8/labels/train... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<00:00, 135.08it/s]
# train: New cache created: /home/n0blespeasant/Desktop/Yolov5Traffic/datasets/coco8/labels/train.cache
# val: Scanning /home/n0blespeasant/Desktop/Yolov5Traffic/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<00:00, 583.74it/s]
# val: New cache created: /home/n0blespeasant/Desktop/Yolov5Traffic/datasets/coco8/labels/val.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3         0G      1.411      2.816      1.757         22        640: 100%|██████████| 1/1 [00:03<00:00,  3.62s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.50s/it]
#                    all          4         17      0.613      0.883      0.888      0.616
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3         0G      1.244      2.677      1.429         23        640: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
#                    all          4         17      0.598      0.897      0.888      0.618
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3         0G      1.127      4.176      1.486         16        640: 100%|██████████| 1/1 [00:03<00:00,  3.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
#                    all          4         17      0.579      0.833      0.874      0.613
# 3 epochs completed in 0.007 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.109 🚀 Python-3.12.9 torch-2.6.0+cu124 CPU (12th Gen Intel Core(TM) i5-1245U)
# Model summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
#                    all          4         17      0.598      0.898      0.888      0.618
#                 person          3         10      0.646        0.5       0.52       0.29
#                    dog          1          1      0.317          1      0.995      0.597
#                  horse          1          2      0.689          1      0.995      0.598
#               elephant          1          2      0.629      0.887      0.828      0.332
#               umbrella          1          1      0.539          1      0.995      0.995
#           potted plant          1          1      0.769          1      0.995      0.895
# Speed: 5.4ms preprocess, 224.0ms inference, 0.0ms loss, 3.8ms postprocess per image
# Results saved to runs/detect/train
# Ultralytics 8.3.109 🚀 Python-3.12.9 torch-2.6.0+cu124 CPU (12th Gen Intel Core(TM) i5-1245U)
# Model summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
# val: Scanning /home/n0blespeasant/Desktop/Yolov5Traffic/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
#                    all          4         17      0.598      0.898      0.888      0.618
#                 person          3         10      0.646        0.5       0.52       0.29
#                    dog          1          1      0.317          1      0.995      0.597
#                  horse          1          2      0.689          1      0.995      0.598
#               elephant          1          2      0.629      0.887      0.828      0.332
#               umbrella          1          1      0.539          1      0.995      0.995
#           potted plant          1          1      0.769          1      0.995      0.895
# Speed: 2.7ms preprocess, 198.9ms inference, 0.0ms loss, 3.6ms postprocess per image
# Results saved to runs/detect/train2
#
# Downloading https://ultralytics.com/images/bus.jpg to 'bus.jpg'...
# 100%|██████████| 134k/134k [00:00<00:00, 2.81MB/s]
# image 1/1 /home/n0blespeasant/Desktop/Yolov5Traffic/bus.jpg: 640x480 4 persons, 1 bus, 228.9ms
# Speed: 5.1ms preprocess, 228.9ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 480)
# Ultralytics 8.3.109 🚀 Python-3.12.9 torch-2.6.0+cu124 CPU (12th Gen Intel Core(TM) i5-1245U)
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# Collecting onnx>=1.12.0
#   Downloading onnx-1.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting onnxslim
#   Downloading onnxslim-0.1.50-py3-none-any.whl.metadata (4.8 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.21.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: numpy>=1.20 in ./YoloVenv/lib/python3.12/site-packages (from onnx>=1.12.0) (2.1.1)
# Requirement already satisfied: protobuf>=3.20.2 in ./YoloVenv/lib/python3.12/site-packages (from onnx>=1.12.0) (6.30.2)
# Requirement already satisfied: sympy in ./YoloVenv/lib/python3.12/site-packages (from onnxslim) (1.13.1)
# Requirement already satisfied: packaging in ./YoloVenv/lib/python3.12/site-packages (from onnxslim) (24.2)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./YoloVenv/lib/python3.12/site-packages (from sympy->onnxslim) (1.3.0)
# Downloading onnx-1.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 10.2 MB/s eta 0:00:000:00:010:00:0101
# Downloading onnxslim-0.1.50-py3-none-any.whl (144 kB)
# Downloading onnxruntime-1.21.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 8.5 MB/s eta 0:00:008.6 MB/s eta 0:00:01
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Installing collected packages: flatbuffers, onnx, humanfriendly, onnxslim, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 flatbuffers-25.2.10 humanfriendly-10.0 onnx-1.17.0 onnxruntime-1.21.1 onnxslim-0.1.50
#
# requirements: AutoUpdate success ✅ 13.6s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim', 'onnxruntime']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success ✅ 16.1s, saved as 'runs/detect/train/weights/best.onnx' (12.2 MB)
#
# Export complete (16.6s)
# Results saved to /home/n0blespeasant/Desktop/Yolov5Traffic/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train/weights/best.onnx imgsz=640 data=/home/n0blespeasant/Desktop/Yolov5Traffic/YoloVenv/lib/python3.12/site-packages/ultralytics/cfg/datasets/coco8.yaml
# Visualize:       https://netron.app
